# %%
import pandas as pd
import numpy as np

# %%
Atripla = pd.read_csv("/Users/Joey/Downloads/Athena/medication/Atripla.csv", sep='\t')
AIDS = pd.read_csv("/Users/Joey/Downloads/Athena/outcome/AIDS.csv", sep='\t')
CD4 = pd.read_csv("/Users/Joey/Downloads/Athena/outcome/CD4_Cell_Count.csv", sep='\t')
AIDS_full = pd.read_csv("/Users/Joey/Downloads/Athena/outcome/Acquired_immunodeficiency_Syndrome.csv", sep='\t')

# %%
Atripla.head()
# Out:
#        Id        Code                                       Name  \
# 0   28550  D000069278                  Arterial Switch Operation
# 1   76798    17718000                       Ostium primum defect
# 2  313217    49436004                        Atrial fibrillation
# 3  314665     5370000                             Atrial flutter
# 4  434467   204315000  Ostium secundum type atrial septal defect
#
#   Standard Class     Domain   Vocab Validity       Concept
# 0   Main Heading  Procedure    MeSH    Valid  Non-standard
# 1       Disorder  Condition  SNOMED    Valid      Standard
# 2       Disorder  Condition  SNOMED    Valid      Standard
# 3       Disorder  Condition  SNOMED    Valid      Standard
# 4       Disorder  Condition  SNOMED    Valid      Standard

# %%
Atripla_1 = Atripla[Atripla["Name"].str.contains("Atripla", case=False)]

# %%
Atripla_1.to_csv("/Users/Joey/Downloads/Athena/medication/Atripla_1.csv", index=False)

# %%
AIDS_1 = AIDS[AIDS["Name"].str.contains("AIDS")]

# %%
AIDS_1.to_csv("/Users/Joey/Downloads/Athena/outcome/AIDS_1.csv", index=False)

# %%
AIDS_full_1 = AIDS_full[AIDS_full["Name"].str.contains("acquired immunodeficiency syndrome", case=False)]

# %%
AIDS_full_1.to_csv("/Users/Joey/Downloads/Athena/outcome/Acquired_immunodeficiency_Syndrome_1.csv", index=False)

# %%
CD4[CD4["Name"].str.contains("CD4", case=False)]
# Out:
#              Id         Code  \
# 405      778178     PCSMTPLD
# 1443    3229005    763713000
# 1518    3246144    406565005
# 2838    4231976    406565005
# 3132   19139458      D018344
# 3223   35622306    763713000
# 16422  37312274    788674000
# 17095  42513933  9709/1-NULL
# 19321  45919943         1254
# 19390  45935235       162183
# 19458  45947058       162850
# 19471  45949607       160103
# 19472  45949665       160565
#
#                                                     Name    Standard Class  \
# 405    Primary Cutaneous CD4 Positive Small/Medium T-...         Condition
# 1443                ICL - idiopathic CD4 lymphocytopenia  Clinical Finding
# 1518                         CD4 T lymphocyte deficiency  Clinical Finding
# 2838                         CD4 T lymphocyte deficiency          Disorder
# 3132          T-Lymphocytopenia, Idiopathic CD4-Positive      Main Heading
# 3223                      Idiopathic CD4 lymphocytopenia          Disorder
# ...

# %%
CD4_1 = CD4[CD4["Name"].str.contains("CD4", case=False)]

# %%
CD4_1.to_csv("/Users/Joey/Downloads/Athena/outcome/CD4_1.csv", index=False)
